# %%
import nltk, pickle, pandas as pd
from nltk.corpus import wordnet, stopwords
from nltk.tag import pos_tag
from nltk.stem import PorterStemmer, WordNetLemmatizer
from string import punctuation

from nltk.probability import FreqDist
from nltk.classify import NaiveBayesClassifier, accuracy
from nltk.tokenize import word_tokenize
from random import shuffle

# %%
stems = PorterStemmer()
lemms = WordNetLemmatizer()
stopW = stopwords.words("english")

# %%
def preprocess(words):
    # tokenizing, removing stopwords, symbols, and numbers, and
    # lemmatizing/stemming the words
    
    tokens = word_tokenize(words)
    # no num no sym
    words = [word.lower() for word in tokens if word.isalpha]
    
    # no stop
    words = [word for word in words if word not in stopW]
    
    #lem & stem
    words = [stems.stem(word) for word in words]
    words = [lemms.lemmatize(word)for word in words]
    
    return words

# %%
dataset = pd.read_csv("./dataset.csv",encoding="utf-8-sig")

all_words = []
for sent in dataset["text"]:
    for word in preprocess(sent):
        all_words.append(word)

# %%
fd = FreqDist(all_words)
common_words = {word for word in fd.most_common(1000)}

# %%
feature_set = []
for text,category in zip(dataset["text"],dataset["label"]):
    feature = {}
    
    processed_feature = preprocess(text)
    
    for word in processed_feature:
        feature[word] = (word in common_words)
    feature_set.append((feature,category))

# %%
shuffle(feature_set)

split_idx = int(len(feature_set)*0.7)
train_set = feature_set[:split_idx]
test_set = feature_set[split_idx:]

# %%
classifier = NaiveBayesClassifier.train(train_set)
classifier.show_most_informative_features(5)

print(accuracy(classifier,test_set))
# Out:
# Most Informative Features
#                positive5 = False          negati : positi =     12.5 : 1.0
#                  terribl = False          negati : positi =     11.9 : 1.0
#                   someon = False          negati : positi =     11.2 : 1.0
#                  perfect = False          positi : negati =     10.0 : 1.0
#                    anyth = False          negati : positi =      8.3 : 1.0
# 0.7333333333333333

# %%
file = open("./modelT2.pickle","wb")
pickle.dump(classifier,file)
file.close()

# %%
def synanto(words):
    syn = []
    ant = []
    
    for syns in wordnet.synsets(words):
        for lemma in syns.lemmas():
            syn.append(lemma.name())
            for ants in lemma.antonyms():
                ant.append(ants.name())
                
    return syn[:5],ant[:5]

def tagger(words):
    tokens = word_tokenize(words)
    tags = pos_tag(tokens)
    
    return tags

# %%
review = "i hate the food it sucks so bad"

def writeRev():
    rev = input("Insert input txt")
    if len(rev.split()) >= 2:
        print("success")
    else:
        print("try again")


def analyze():
    if review == "":
        print("no reviews")
        return
    rev_tags = tagger(review)
    
    for i,word in enumerate(rev_tags):
        print(f"{i+1}. {word[0]} =  {word[1]}")
    
    tokens = word_tokenize(review.lower())
    
    for word in tokens:
        syno, anto = synanto(word)
        print("="*10)
        print("Word =",word)
        print(f"Synos: {', '.join(syno) if syno else '-'}")
        print(f"Antos: {', '.join(anto) if anto else '-'}")
    
    
    file = open("./modelT2.pickle","rb")
    classer = pickle.load(file)
    file.close()
    
    cleaned_tokens = preprocess(review)
    
    result = classer.classify(FreqDist(cleaned_tokens))
    print("Res =",result)
    
    classer.show_most_informative_features(100)
    
analyze()
# Out:
# 1. i =  NN
# 2. hate =  VBP
# 3. the =  DT
# 4. food =  NN
# 5. it =  PRP
# 6. sucks =  VBZ
# 7. so =  RB
# 8. bad =  JJ
# ==========
# Word = i
# Synos: iodine, iodin, I, atomic_number_53, one
# Antos: -
# ==========
# Word = hate
# Synos: hate, hatred, hate, detest
# Antos: love, love
# ==========
# Word = the
# Synos: -
# Antos: -
# ==========
# Word = food
# Synos: food, nutrient, food, solid_food, food
# Antos: -
# ==========
# Word = it
# Synos: information_technology, IT
# Antos: -
# ==========
# Word = sucks
# Synos: sucking, suck, suction, suck, suck
# Antos: bottlefeed
# ==========
# Word = so
# Synos: sol, soh, so, so, so
# Antos: -
# ==========
# Word = bad
# Synos: bad, badness, bad, bad, big
# Antos: good, goodness, good, unregretful
# Res = positive
# Most Informative Features
#                positive5 = False          negati : positi =     12.5 : 1.0
#                  terribl = False          negati : positi =     11.9 : 1.0
#                   someon = False          negati : positi =     11.2 : 1.0
#                  perfect = False          positi : negati =     10.0 : 1.0
#                    anyth = False          negati : positi =      8.3 : 1.0
#                     rude = False          negati : positi =      7.4 : 1.0
#                   receiv = False          negati : positi =      6.8 : 1.0
#                     wors = False          negati : positi =      6.8 : 1.0
#                    entre = False          positi : negati =      6.6 : 1.0
#                    entir = False          negati : positi =      6.4 : 1.0
#                   immedi = False          negati : positi =      6.1 : 1.0
#                      man = False          negati : positi =      6.1 : 1.0
#                  possibl = False          negati : positi =      6.1 : 1.0
#                  request = False          negati : positi =      6.1 : 1.0
#                   beauti = False          positi : negati =      5.9 : 1.0
#                     damn = False          positi : negati =      5.9 : 1.0
#                   frozen = False          negati : positi =      5.5 : 1.0
#                    greet = False          negati : positi =      5.5 : 1.0
#                      low = False          negati : positi =      5.5 : 1.0
#                      pas = False          negati : positi =      5.5 : 1.0
#                   rather = False          negati : positi =      5.5 : 1.0
#                      sad = False          negati : positi =      5.5 : 1.0
#                    quiet = False          positi : negati =      5.2 : 1.0
#                    local = False          positi : negati =      4.9 : 1.0
#                  employe = False          negati : positi =      4.8 : 1.0
#                    gross = False          negati : positi =      4.8 : 1.0
#                   lettuc = False          negati : positi =      4.8 : 1.0
#                    manag = False          negati : positi =      4.8 : 1.0
#                      tip = False          negati : positi =      4.8 : 1.0
#                      bad = False          negati : positi =      4.6 : 1.0
#                   butter = False          positi : negati =      4.5 : 1.0
#                    heart = False          positi : negati =      4.5 : 1.0
#                    patio = False          positi : negati =      4.5 : 1.0
#                 pleasant = False          positi : negati =      4.5 : 1.0
#                    south = False          positi : negati =      4.5 : 1.0
#                    yummi = False          positi : negati =      4.5 : 1.0
#                     lack = False          negati : positi =      4.4 : 1.0
#                    point = False          negati : positi =      4.4 : 1.0
#                    coffe = False          positi : negati =      4.4 : 1.0
#                     five = False          positi : negati =      4.4 : 1.0
#                    onion = False          positi : negati =      4.4 : 1.0
#                atmospher = False          positi : negati =      4.3 : 1.0
#                    apart = False          negati : positi =      4.2 : 1.0
#                  appoint = False          negati : positi =      4.2 : 1.0
#                     drop = False          negati : positi =      4.2 : 1.0
#                 otherwis = False          negati : positi =      4.2 : 1.0
#                     save = False          negati : positi =      4.2 : 1.0
#                   simpli = False          negati : positi =      4.2 : 1.0
#                    sleep = False          negati : positi =      4.2 : 1.0
#                    smell = False          negati : positi =      4.2 : 1.0
#                   overpr = False          negati : positi =      4.0 : 1.0
#                     sign = False          negati : positi =      4.0 : 1.0
#                      let = False          negati : positi =      3.9 : 1.0
#                    cream = False          positi : negati =      3.9 : 1.0
#                    excel = False          positi : negati =      3.9 : 1.0
#                      boy = False          positi : negati =      3.8 : 1.0
#                      cup = False          positi : negati =      3.8 : 1.0
#                   garlic = False          positi : negati =      3.8 : 1.0
#                 mushroom = False          positi : negati =      3.8 : 1.0
#                   prefer = False          positi : negati =      3.8 : 1.0
#                    refil = False          positi : negati =      3.8 : 1.0
#                    smile = False          positi : negati =      3.8 : 1.0
#                      wow = False          positi : negati =      3.8 : 1.0
#                     cold = False          negati : positi =      3.7 : 1.0
#                    green = False          positi : negati =      3.7 : 1.0
#                     issu = False          negati : positi =      3.7 : 1.0
#                    addit = False          negati : positi =      3.5 : 1.0
#                      box = False          negati : positi =      3.5 : 1.0
#                    break = False          negati : positi =      3.5 : 1.0
#                   cancel = False          negati : positi =      3.5 : 1.0
#                  cheaper = False          negati : positi =      3.5 : 1.0
#                 complain = False          negati : positi =      3.5 : 1.0
#                  counter = False          negati : positi =      3.5 : 1.0
#                   depart = False          negati : positi =      3.5 : 1.0
#                   follow = False          negati : positi =      3.5 : 1.0
#                     hold = False          negati : positi =      3.5 : 1.0
#                    ignor = False          negati : positi =      3.5 : 1.0
#                   member = False          negati : positi =      3.5 : 1.0
#                    middl = False          negati : positi =      3.5 : 1.0
#                 needless = False          negati : positi =      3.5 : 1.0
#                positive2 = False          negati : positi =      3.5 : 1.0
#                     sent = False          negati : positi =      3.5 : 1.0
#                 thursday = False          negati : positi =      3.5 : 1.0
#                     tini = False          negati : positi =      3.5 : 1.0
#                     zero = False          negati : positi =      3.5 : 1.0
#                    anyon = False          negati : positi =      3.4 : 1.0
#                     hope = False          negati : positi =      3.4 : 1.0
#                       ok = False          negati : positi =      3.3 : 1.0
#                      old = False          negati : positi =      3.3 : 1.0
#                      bag = False          negati : positi =      3.3 : 1.0
#                     fish = False          negati : positi =      3.3 : 1.0
#                   custom = False          negati : positi =      3.2 : 1.0
#                     leav = False          negati : positi =      3.2 : 1.0
#                      \ni = False          positi : negati =      3.1 : 1.0
#                    capit = False          positi : negati =      3.1 : 1.0
#                  countri = False          positi : negati =      3.1 : 1.0
#                   delici = False          positi : negati =      3.1 : 1.0
#                      dip = False          positi : negati =      3.1 : 1.0
#                    futur = False          positi : negati =      3.1 : 1.0
#                 guarante = False          positi : negati =      3.1 : 1.0
